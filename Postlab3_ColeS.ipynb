# %% [markdown]
# # Post-Lab Questions, Lab 3
# Labs are completed collaboratively, but PostLabs should be completed individually.  You are allowed to share ideas with others, but the work you submit for this assignment should be your own (your own plots, your own words, nothing AI generated).

# %% [markdown]
# Name:    <span style = 'background-color:yellow'>Cole Stevens</span>

# %% [markdown]
# 1. In one paragraph, summarize what you did in this lab and what the lab was about.

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 1:<br>
# In this lab, I learned how to use a Digital Multimeter (DMM) and Oscilloscope (OSC) to measure the frequency, period, amplitude, and peak-to-peak voltage of an unknown AC signal. I learned how to collect data from the OSC and plot it to produce a sine wave.
# Next I rebuilt a two-divider circuit connected to the power supply and DMM. I remeasured the gain from each subcircuit and combined circuit, and repeated it when reversing the subcircuits. Then I learned how to use a buffer and incorporate it into the two-divider circuit. Using that I found how it kept the sub-circuits (the dividers) from loading into each other.
# </span>

# %% [markdown]
# 2.  For a given periodic signal, say $V(t)$, its rms value is $V_\text{rms}$, where $V_\text{rms}=\sqrt{<V(t)^{2}>_{t}} = \sqrt{\frac{1}{T}\int_{0}^{T}V(t)^2\;dt}$ .  ($<...>_\text{t}$ is generally used to denote an average taken over a long time, which for a periodic function is equivalent to an average taken over a period.)  Is $V_\text{rms}$ independent of the period, $T$, of $V(t)$?  Why or why not?

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 2:<br>
# $V_\text{rms}$ is not independent of $T$ or $V(t)$. It can clearly be seen from the formula that $T$ and $V(t)$ are critical variables of $V_\text{rms}$. Any change of those variables changes the value of $V_\text{rms}$.
# </span>

# %% [markdown]
# 3.  Calculate the rms voltage for a triangle wave of amplitude $A$.

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 3:<br>
#
# ![Problem3 Postlab3.jpg](attachment:1aae4797-e750-4154-b974-67f96f9a859e.jpg)
# </span>

# %% [markdown]
# 4.  Consider the loaded Thevenin circuit below.
#
#    ![Thevenin_loaded.JPG](attachment:0e6f323f-b1ad-4227-b46f-7dcf531e3b8d.JPG)
#
#    Let's consider the power through the load as a function of the load resistance, $P_\text{L}(R_\text{L})$:
#
#    $P_\text{L}(R_\text{L}) = I_\text{L}V_\text{L}$
#
#    $P_\text{L}(R_\text{L}) = \frac{V_\text{L}^{2}}{R_\text{L}}$  (using Ohm's Law)
#
#    $P_\text{L}(R_\text{L}) = \frac{(V_\text{Th}G)^{2}}{R_\text{L}}$  (using the definition of gain, $G = \frac{V_\text{L}}{V_\text{Th}}$)
#
#    $P_\text{L}(R_\text{L}) = V_\text{Th}^{2}\frac{(G(R_\text{L}))^{2}}{R_\text{L}}$  ($V_\text{Th}$ is a constant, $G(R_\text{L})$ is the gain as a function of the load resistance)
#
#    Find $G(R_\text{L})$, and insert it into the equation for power above.  Then find $R_\text{L}$ such that $P_\text{L}(R_\text{L})$ is maximized.  What is this value of $R_\text{L}$, and what is the maximum value of power?
#
#    (Note:  You may do this by hand or with `sympy`, or both.  In any case, make sure your work and reasoning are clearly communicated.)

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 4:</span>
#
# ![Problem4 Postlab3.jpg](attachment:df044ad4-7f82-4b90-a0eb-f775b0e34887.jpg)

# %% [markdown]
# 5.  Find the Thevenin Equivalent circuit for a voltage divider.  The voltage divider is given in terms of $V_\text{in}$, $R_\text{1}$, and $R_\text{2}$.

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 5:</span>
# ![Problem5 postlab3.jpg](attachment:3432b253-e6e9-4f02-bc86-4b3199b65029.jpg)

# %% [markdown]
# 6a.  Find the Thevenin equivalent circuit for the circuit below.  Use $V_1=28\ \text{V}$, $V_2=7\ \text{V}$, $R_1=4\ \Omega$, $R_2=1\ \Omega$.
#
# ![Thevenin_MM.png](attachment:27b60268-e72a-4116-932a-8733c9d8501c.png)

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 6a:</span>
#
# * $V_\text{Th}=$ 11.2 V
# * $R_\text{Th}=$ 0.8 $\ohm$
#
# ![Problem6a Postlab3.jpg](attachment:91485048-d920-4b37-b616-99a8c4aa2ca7.jpg)

# %% [markdown]
# 6b.  Then, build the original circuit and the Thevenin equivalent on Falstad, and show that they deliver the same current through and voltage across various load resistors.  Summarize your results in a table.

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 6b:</span> <br>
# For Voltage Measured:<br>
# ![Problem 6b voltage10.png](attachment:4c5ad5c3-6e7d-4302-9edd-4f529ab202da.png)
# ![Problem 6b voltage25.png](attachment:0eafcbb7-d40f-418d-b11d-2c04e09ee0cf.png)
# ![Problem 6b voltage60.png](attachment:9ba3870a-933e-479b-828e-3d3a14271c03.png)
#
#
# For Current Measured:<br>
# ![Problem 6b current10.png](attachment:9975f656-4d93-467d-b938-84baa713b88c.png)
# ![Problem 6b current25.png](attachment:e0457536-e0b3-4a98-9c78-66bcf146e329.png)
# ![Problem 6b current60.png](attachment:2e783b5e-01ca-42d3-9222-dab782dd622c.png)
#
#
# Table:
# |Load Resistor|Voltage (V) OG| Voltage (V) Th|
# |-------------|--------------|---------------|
# |     10      |      10.37   |      10.37    |
# |25           |10.853        |10.853         |
# |60           |11.053        |11.053         |
# |1000         |11.191        |  11.191       |
#
# |Load Resistor|Current (A) OG| Current (A) Th|
# |-------------|--------------|---------------|
# |10           |14            |14             |
# |25           |14            |14             |
# |60           | 14           |  14           |
# |1000         | 14           |     14        |

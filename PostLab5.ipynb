# %% [markdown]
# # Post-Lab Questions, Lab 5
# Labs are completed collaboratively, but PostLabs should be completed individually.  You are allowed to share ideas with others, but the work you submit for this assignment should be your own (your own plots, your own words, nothing AI generated).

# %% [markdown]
# Name:    <span style = 'background-color:yellow'>Cole Stevens</span>

# %% [markdown]
# 1. In one paragraph, summarize what you did in this lab and what the lab was about.

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 1:</span> <br>
# This lab was about us. It was about us designing our own circuits and our own procedures to accomplish the goal given to us. For this lab it was to design a circuit to filter and isolate frequencies of our choosing, and then test the limits of our circuit's ability to do so. <br>
# In this lab I designed an RC Band-pass circuit with an op amp to filter an AC ramp signal with 80% symmetry to isolate the frequency signals of 1500 Hz and 2250 Hz. I also designed how I would test the limits of this circuit and the procedure for going about to do that. I also conducted troubleshooting with gain plots to visualize the performance of my circuit.

# %% [markdown]
# 2. Calculate the gain for the non-inverting amplifier shown below.
#
# ![non-inverting-amp.png](attachment:4a88618e-4478-4fbf-aba3-2cf0153ee3a9.png)

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 2:</span> <br>
# v+ = V_in<br>
# v- = v+<br>
# I_in = V_in / R_1<br>
# I_out = I_in<br>
# V_feedback = - (I_out * R_1)<br>
# V_out = I_in * R_2
# ![Postlab5 Prob2.jpg](attachment:8a9f6614-c8ed-4f25-8105-5e6d1de8eb1b.jpg)
# (Calculations)
#
# $|G_\text{NIamp}| = R_\text{2} / R_\text{1}$

# %% [markdown]
# 3. Calculate the magnitude of the gain for the high-pass filter shown below:
#
# ![highpass-opamp.png](attachment:96f8d0c5-244a-46be-820f-3fe305b4f9d4.png)

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 3:</span>  <br>
# v+ = 0<br>
# v- = 0<br>
# I_in = V_in / R_in<br>
# I_out = I_in<br>
# V_feedback = I_in * R_f<br>
# V_out = - V_in( R_f * R_in )
# |G| = V_out / V_in
# ![Postlab5 Prob3.jpg](attachment:0cd4c6a9-1565-4143-8e62-a602123d1fb1.jpg)
# (Calculations)
#
# $|G_\text{HPopamp}| = R_\text{f} / R_\text{in}$

# %% [markdown]
# 4.  Use Falstad to show that your answer to 3 is correct.  Take $C = 10\;\mu F$.  Choose $R_\text{in}$ and $R_\text{f}$ such that your critical frequency is at 1 kHz, and you have a gain of 3 at this critical frequency.  How is it possible to have a gain greater than 1?  Explain any discrepancies you might observe between your expected values and your Falstad data.

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 4:</span>  <br>
# f_c = 1 / (2 $\pi$R*C)<br>
# R = 1 / (2 $\pi$C*f_c)
# R = 16 $\ohm$
# (Calculations)
# ![Postlab5 Prob4.png](attachment:8900ced3-280c-4816-853f-f71df8c8e8b6.png)
# $R_\text{in} = 6$
#
# $R_\text{f} = 10$
#
# (How can gain be greater than 1?)
#
# (Comments re: plot)

# %%
#plot Falstad data against function from problem 3

# %% [markdown]
# 5.  For lab 5, say that you chose the series RLC circuit to as your tunable band-pass filter (See AHA5_1).  You kept a constant $R$ and $C$, and varied $L$ using a variable inductor box.  Your gain peak was wider and smaller than expected; your instructor says this may be due to resistance in the inductor box.  Model this extra resistance as a $200\;\Omega$ resistor that is in parallel with your inductor.  Choose $L = 200\;mH$, $C = 33\;\mu F$, and your regular resistor to be $R = 100\;\Omega$.  Use Falstad to take data and plot the two overlapping gain curves; one with the extra resistor (in parallel with the inductor) and one without.  Does the qualitative effect of the extra resistance in the inductor box match what you observed in lab?

# %% [markdown]
# <span style = 'background-color:yellow'>Answer to Problem 5:</span>  (Student Answer Here)

# %%
#code for plots here
